# %%
import cassiopeia as cass
from cassiopeia import Summoner, Match
from cassiopeia.data import Season, Queue
from collections import Counter
from ratelimit import limits, sleep_and_retry
import arrow
import requests
import pandas as pd
import datetime

@sleep_and_retry
@limits(calls=20, period=1)
@limits(calls=100, period=120)
def get_full_match_history(key, summoner):
    data = {
        "X-Riot-Token": key
    }
    
    total_matches = 0
    fetched_records = 1
    full_history = None

    while fetched_records > 0:
        print(f"Fetching records {total_matches} to {total_matches+100}")
        
        query = "https://americas.api.riotgames.com/lol/match/v5/matches/by-puuid/{puuid}/ids?start={start}&count={count}".format(puuid=summoner.puuid,
                                                                                                                                  start=total_matches,
                                                                                                                                  count=100)
        
        response = requests.get(query, headers=data)
        
        history = response.content.decode('UTF-8').replace('"',"").strip("[]").split(",")
        
        history = [ele for ele in history if ele != ""]

        if full_history is None:
            full_history = history
        else:
            full_history.extend(history)
            
        fetched_records = len(history)
        total_matches = total_matches + fetched_records

    return full_history

def start_error(row):
    try:
        return row.match.creation#pd.to_datetime(row.match.creation.datetime, utc=True)  
    except:
        return 0#return arrow.get('1980-01-01')#datetime(1980,1,1,0,0,0).replace(tzinfo=timezone.utc)
    
def duration_error(row):
    try:
        return row.match.duration
    except:
        return 0
    
def result(row):
    return {'name': row.summoner.name,  'result': row.stats.win}

def get_wins(match, name):
    try:
        results = pd.DataFrame(map(result, match.participants)).drop_duplicates()
        if results['result'][results['name'] == name].values[0] == True:
            return 'Win'
        elif results['result'][results['name'] == name].values[0] == False:
            return 'Loss'
        else:
            return 'Other'
    except:
        return 'Other'

def add_times(start, duration):
    return start + duration

def create_player_stats(key, player, role):
    cass.set_riot_api_key(key)

    summoner = Summoner(name=player, region="NA")

    match_history = get_full_match_history(key, summoner)

    print(f'Finished pulling {summoner.name}, they had {len(match_history)} games on this account')

    games = pd.DataFrame()
    games['match_id'] = match_history
    games['match'] = games.apply(lambda row: Match(id=row.match_id, region='NA'), axis = 1)
    games['start_time'] = games.apply(lambda row: start_error(row), axis = 1)
    games['duration'] = games.apply(lambda row: duration_error(row), axis = 1)
    games['end_time'] = games.apply(lambda row: add_times(row['start_time'], row['duration']), axis = 1)
    games = games.loc[(games['start_time'] != 0) & (games['duration'] != 0) & (games['end_time'] != 0)]
    games = games.loc[games['start_time'] >= arrow.get('2022-01-01')]
    games['player'] = summoner.name
    games['results'] = games.apply(lambda x: get_wins(x['match'], x['player']), axis = 1)
    games['start_next'] = games.groupby('player').start_time.shift(1)

    play_sessions = [1]
    session_count = 1

    for i in range(1, len(games)):
        if (games['start_next'][i] - games['end_time'][i]) > datetime.timedelta(seconds = 1800):
            session_count += 1
        play_sessions.append(session_count)

    games['sessions'] = play_sessions

    grp = games.groupby('sessions')
    grp_out = grp.agg(win_count = ('results', lambda x: (x=='Win').sum()), loss_count = ('results', lambda x: (x=='Loss').sum()), session_start = ('start_time', min), session_end = ('end_time', max))
    grp_out.reset_index(inplace=True)
    grp_out['next_session'] = grp_out['sessions'] - 1
    grp_out['start_next_session'] = grp_out.merge(grp_out, left_on="next_session", right_on="sessions", how='left')['session_start_y']
    grp_out['total_count'] = grp_out['win_count'] + grp_out['loss_count']
    grp_out['win_ratio'] = grp_out['win_count'] / grp_out['total_count']
    grp_out['session_length'] = grp_out['session_end'] - grp_out['session_start']
    grp_out['time_until_next_session'] = grp_out['start_next_session'] - grp_out['session_end']

    stats = {'player': games['player'][0], 'role': role, 'avg_games_per_session': grp_out['total_count'].mean(), 'avg_length_of_session': grp_out['session_length'].mean(), \
             'avg_length_of_winning_session': grp_out['session_length'].loc[grp_out['win_ratio'] > 0.5].mean(), \
             'avg_length_of_losing_session': grp_out['session_length'].loc[grp_out['win_ratio'] < 0.5].mean(), \
             'avg_length_of_even_session': grp_out['session_length'].loc[grp_out['win_ratio'] == 0.5].mean(), 'avg_length_of_break': grp_out['time_until_next_session'].mean(), \
             'avg_length_of_break_after_winning': grp_out['time_until_next_session'].loc[grp_out['win_ratio'] > 0.5].mean(), \
             'avg_length_of_break_after_losing': grp_out['time_until_next_session'].loc[grp_out['win_ratio'] < 0.5].mean(), \
             'avg_length_of_break_after_even': grp_out['time_until_next_session'].loc[grp_out['win_ratio'] == 0.5].mean()}
    
    return stats


players = ['Nebs97', 'djruhnke', 'Elend Venture', 'EnderAWiggin', 'lentzf', 'GiveEmSomePepper', 'BoatRaceGod', 'NatGlanzman', 'shakaynery', 'LordZooplankton']
pros = ['blaberfish2', 'TF Blade', 'Doublelift', 'Smoothie', 'Ssumdayday', 'Meteos', 'Ablazeolive', 'Imaqtpie', 'Shiphtur', 'AnDa']
combined_stats = pd.DataFrame()

for p in players:
    stats = create_player_stats('RGAPI-38abfb73-273e-4606-b82d-7ec25c72228c', p, 'non_pro')
    player_stats = pd.DataFrame(data=stats, index=[0])
    combined_stats = pd.concat([combined_stats, player_stats], axis = 0, sort = False).reset_index(drop = True)

for p in pros:
    stats = create_player_stats('RGAPI-38abfb73-273e-4606-b82d-7ec25c72228c', p, 'pro')
    player_stats = pd.DataFrame(data=stats, index=[0])
    combined_stats = pd.concat([combined_stats, player_stats], axis = 0, sort = False).reset_index(drop = True)
# Out:
# Fetching records 0 to 100
# Fetching records 100 to 200
# Fetching records 200 to 300
# Fetching records 300 to 400
# Fetching records 400 to 500
# Fetching records 500 to 600
# Fetching records 583 to 683
# Finished pulling Nebs97, they had 583 games on this account
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4355408942
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_4355391932
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3938060270
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930155743
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929996307
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929956507
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3938060270
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930155743
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929996307
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929956507
# Fetching records 0 to 100
# Fetching records 100 to 200
# Fetching records 200 to 300
# Fetching records 300 to 400
# Fetching records 400 to 500
# Fetching records 500 to 600
# Fetching records 600 to 700
# Fetching records 700 to 800
# Fetching records 800 to 900
# Fetching records 900 to 1000
# Fetching records 988 to 1088
# Finished pulling Djruhnke, they had 988 games on this account
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930145973
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930115836
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929996307
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929836682
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930145973
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930115836
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929996307
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929836682
# Fetching records 0 to 100
# Fetching records 100 to 200
# Fetching records 200 to 300
# Fetching records 300 to 400
# Fetching records 400 to 500
# Fetching records 500 to 600
# Fetching records 600 to 700
# Fetching records 700 to 800
# Fetching records 800 to 900
# Fetching records 900 to 1000
# Fetching records 987 to 1087
# Finished pulling Elend Venture, they had 987 games on this account
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930126002
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929836682
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929836630
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930126002
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929836682
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929836630
# Fetching records 0 to 100
# Fetching records 100 to 200
# Fetching records 200 to 300
# Fetching records 300 to 400
# Fetching records 400 to 500
# Fetching records 500 to 600
# Fetching records 600 to 700
# Fetching records 700 to 800
# Fetching records 725 to 825
# Finished pulling EnderAWiggin, they had 725 games on this account
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930126049
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930016107
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930015988
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929956468
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930126049
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930016107
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930015988
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3929956468
# Fetching records 0 to 100
# Fetching records 100 to 200
# Fetching records 200 to 300
# Fetching records 300 to 400
# Fetching records 400 to 500
# Fetching records 500 to 600
# Fetching records 600 to 700
# Fetching records 700 to 800
# Fetching records 800 to 900
# Fetching records 900 to 1000
# Fetching records 994 to 1094
# Finished pulling lentzf, they had 994 games on this account
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930145973
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930145919
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930115869
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930115836
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3901325327
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3901325277
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3901325165
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3757852967
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3757826986
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930145973
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930145919
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930115869
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3930115836
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3901325327
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3901325277
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3901325165
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3757852967
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/NA1_3757826986
# Fetching records 0 to 100
# Fetching records 100 to 200
# Fetching records 102 to 202
# Fetching records 104 to 204
# Fetching records 106 to 206
# Fetching records 108 to 208
# Fetching records 110 to 210
# Fetching records 112 to 212
# Fetching records 114 to 214
# Fetching records 116 to 216
# Fetching records 118 to 218
# Fetching records 120 to 220
# Fetching records 122 to 222
# Fetching records 124 to 224
# Fetching records 126 to 226
# Fetching records 128 to 228
# Fetching records 130 to 230
# Fetching records 132 to 232
# Fetching records 134 to 234
# Fetching records 136 to 236
# Fetching records 138 to 238
# Fetching records 140 to 240
# Fetching records 142 to 242
# Fetching records 144 to 244
# Fetching records 146 to 246
# Fetching records 148 to 248
# Fetching records 150 to 250
# Fetching records 152 to 252
# Fetching records 154 to 254
# Fetching records 156 to 256
# Fetching records 158 to 258
# Fetching records 160 to 260
# Fetching records 162 to 262
# Fetching records 164 to 264
# Fetching records 166 to 266
# Fetching records 168 to 268
# Fetching records 170 to 270
# Fetching records 172 to 272
# Fetching records 174 to 274
# Fetching records 176 to 276
# Fetching records 178 to 278
# Fetching records 180 to 280
# Fetching records 182 to 282
# Fetching records 184 to 284
# Fetching records 186 to 286
# Fetching records 188 to 288
# Fetching records 190 to 290
# Fetching records 192 to 292
# Fetching records 194 to 294
# Fetching records 196 to 296
# Fetching records 198 to 298
# Fetching records 200 to 300
# Fetching records 202 to 302
# Fetching records 204 to 304
# Fetching records 206 to 306
# Fetching records 208 to 308
# Fetching records 210 to 310
# Fetching records 212 to 312
# Fetching records 214 to 314
# Fetching records 216 to 316
# Fetching records 218 to 318
# Fetching records 220 to 320
# Fetching records 222 to 322
# Fetching records 224 to 324
# Fetching records 226 to 326
# Fetching records 228 to 328
# Fetching records 230 to 330
# Fetching records 232 to 332
# Fetching records 234 to 334
# Fetching records 236 to 336
# Fetching records 238 to 338
# Fetching records 240 to 340
# Fetching records 242 to 342
# Fetching records 244 to 344
# Fetching records 246 to 346
# Fetching records 248 to 348
# Fetching records 250 to 350
# Fetching records 252 to 352
# Fetching records 254 to 354
# Fetching records 256 to 356
# Fetching records 258 to 358
# Fetching records 260 to 360
# Fetching records 262 to 362
# Fetching records 264 to 364
# Fetching records 266 to 366
# Fetching records 268 to 368
# Fetching records 270 to 370
# Fetching records 272 to 372
# Fetching records 274 to 374
# Fetching records 276 to 376
# Fetching records 278 to 378
# Fetching records 280 to 380
# Fetching records 282 to 382
# Fetching records 284 to 384
# Fetching records 286 to 386
# Fetching records 288 to 388
# Fetching records 290 to 390
# Fetching records 292 to 392
# Fetching records 294 to 394
# Fetching records 296 to 396
# Fetching records 298 to 398
# Fetching records 300 to 400
# Fetching records 302 to 402
# Fetching records 304 to 404
# Fetching records 306 to 406
# Fetching records 308 to 408
# Fetching records 310 to 410
# Fetching records 312 to 412
# Fetching records 314 to 414
# Fetching records 316 to 416
# Fetching records 318 to 418
# Fetching records 320 to 420
# Fetching records 322 to 422
# Fetching records 324 to 424
# Fetching records 326 to 426
# Fetching records 328 to 428
# Fetching records 330 to 430
# Fetching records 332 to 432
# Fetching records 334 to 434
# Fetching records 336 to 436
# Fetching records 338 to 438
# Fetching records 340 to 440
# Fetching records 342 to 442
# Fetching records 344 to 444
# Fetching records 346 to 446
# Fetching records 348 to 448
# Fetching records 350 to 450
# Fetching records 352 to 452
# Fetching records 354 to 454
# Fetching records 356 to 456
# Fetching records 358 to 458
# Fetching records 360 to 460
# Fetching records 362 to 462
# Fetching records 364 to 464
# Fetching records 366 to 466
# Fetching records 368 to 468
# Fetching records 370 to 470
# Fetching records 372 to 472
# Fetching records 374 to 474
# Fetching records 376 to 476
# Fetching records 378 to 478
# Fetching records 380 to 480
# Fetching records 382 to 482
# Fetching records 384 to 484
# Fetching records 386 to 486
# Fetching records 388 to 488
# Fetching records 390 to 490
# Fetching records 392 to 492
# Fetching records 394 to 494
# Fetching records 396 to 496
# Fetching records 398 to 498
# Fetching records 400 to 500
# Fetching records 402 to 502
# Fetching records 404 to 504
# Fetching records 406 to 506
# Fetching records 408 to 508
# Fetching records 410 to 510
# Fetching records 412 to 512
# Fetching records 414 to 514
# Fetching records 416 to 516
# Fetching records 418 to 518
# Fetching records 420 to 520
# Fetching records 422 to 522
# Fetching records 424 to 524
# Fetching records 426 to 526
# Fetching records 428 to 528
# Fetching records 430 to 530
# Fetching records 432 to 532
# Fetching records 434 to 534
# Fetching records 436 to 536
# Fetching records 438 to 538
# Fetching records 440 to 540
# Fetching records 442 to 542
# Fetching records 444 to 544
# Fetching records 446 to 546
# Fetching records 448 to 548
# Fetching records 450 to 550
# Fetching records 452 to 552
# Fetching records 552 to 652
# Fetching records 620 to 720
# Finished pulling GiveEmSomePepper, they had 620 games on this account
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/{status:{message:Rate limit exceeded
# Making call: https://americas.api.riotgames.com/lol/match/v5/matches/status_code:429}}

# %%
combined_stats

# %%
import plotly.graph_objects as go

# df = pd.DataFrame([
#     dict(Task="Job A", Start='2009-01-01', Finish='2009-02-28'),
#     dict(Task="Job B", Start='2009-03-05', Finish='2009-04-15'),
#     dict(Task="Job C", Start='2009-02-20', Finish='2009-05-30')
# ])

fig = go.timeline(games, x_start="start_time", x_end="end_time", y="player", color="player", color_discrete_sequence = ['red'], opacity=1)
fig.update_yaxes(autorange="reversed") # otherwise tasks are listed from the bottom up
fig.update_xaxes(range=['2022-01-20 18:15:29+00:00', '2022-06-20 18:15:29+00:00'])
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [155], in <cell line: 9>()
#       1 import plotly.graph_objects as go
#       3 # df = pd.DataFrame([
#       4 #     dict(Task="Job A", Start='2009-01-01', Finish='2009-02-28'),
#       5 #     dict(Task="Job B", Start='2009-03-05', Finish='2009-04-15'),
#       6 #     dict(Task="Job C", Start='2009-02-20', Finish='2009-05-30')
#       7 # ])
# ----> 9 fig = go.timeline(games, x_start="start_time", x_end="end_time", y="player", color="player", color_discrete_sequence = ['red'], opacity=1)
#      10 fig.update_yaxes(autorange="reversed") # otherwise tasks are listed from the bottom up
#      11 fig.update_xaxes(range=['2022-01-20 18:15:29+00:00', '2022-06-20 18:15:29+00:00'])
#
# File ~\anaconda3\lib\site-packages\plotly\graph_objects\__init__.py:298, in __getattr__(import_name)
#     294         from ..missing_ipywidgets import FigureWidget
#     296         return FigureWidget
# --> 298 return orig_getattr(import_name)
#
# File ~\anaconda3\lib\site-packages\_plotly_utils\importers.py:39, in relative_import.<locals>.__getattr__(import_name)
#      36     class_module = importlib.import_module(rel_module, parent_name)
#      37     return getattr(class_module, class_name)
# ---> 39 raise AttributeError(
#      40     "module {__name__!r} has no attribute {name!r}".format(
#      41         name=import_name, __name__=parent_name
#      42     )
#      43 )
#
# AttributeError: module 'plotly.graph_objects' has no attribute 'timeline'

# %%
# Average games/session
# Average play session length
# Average play session length on losing day
# Average play session length on winning day
